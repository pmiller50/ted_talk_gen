# %% [markdown]
# Capstone
#
# Scrape this page to get list of TED talk urls.
#
# https://www.ted.com/talks?language=en&page=1&sort=newest
#
# Another notebook will then import csv file list of urls to scrape the actual transcripts.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time

# %%
# # Load list of urls that will contain a url for each TED talk
# list_of_talks = pd.read_csv('talk_list.csv')

# If running this notebook several times to try to download missing talks, we should import the updated transcripts.csv file 
list_of_talks = pd.read_csv('transcripts.csv')
list_of_talks.head()
# Out:
#                                                title  \
# 0  Community-powered solutions to the climate crisis
# 1         A simple 2-step plan for saving more money
# 2  What causes dandruff, and how do you get rid o...
# 3    The artist who won a Nobel Prize... in medicine
# 4         A concrete idea to reduce carbon emissions
#
#                                  speaker  \
# 0  Rahwa Ghirmatzion and Zelalem Adefris
# 1                       Wendy De La Rosa
# 2                       Thomas L. Dawson
# 3                      Melanie E. Peffer
# 4                        Karen Scrivener
#
#                                                  url month  year  \
# 0  /talks/rahwa_ghirmatzion_and_zelalem_adefris_c...   Feb  2021
# 1  /talks/wendy_de_la_rosa_a_simple_2_step_plan_f...   Feb  2021
# 2  /talks/thomas_l_dawson_what_causes_dandruff_an...   Feb  2021
# 3  /talks/melanie_e_peffer_the_artist_who_won_a_n...   Feb  2021
# 4  /talks/karen_scrivener_a_concrete_idea_to_redu...   Feb  2021
#
#                                                 tags                 views  \
# 0  climate change,Countdown,activism,community,so...  400,245 views • 4:32
# 1                    goal-setting,finance,self,money        0 views • 2:41
# 2  TED-Ed,education,human body,animation,science,...        0 views • 4:51
# 3  animation,education,TED-Ed,history,science,bra...   92,521 views • 4:49
# 4  Countdown,materials,climate change,innovation,...  589,372 views • 4:26
#
#                                           transcript
# 0  Don Cheadle: Home. It's where we celebrate our...
# 1  Everyone's heard of the tired old adage of pay...
# 2  Here in this abundant forest, Malassezia is eq...
# 3  In the late 1860s, scientists believed they we...
# 4  Concrete is the second most used substance on ...

# %%
list_of_talks.shape
# Out:
# (4384, 8)

# %%
# Each TED talk transcript is a url in the form of:
#https://www.ted.com/talks/rahwa_ghirmatzion_and_zelalem_adefris_community_powered_solutions_to_the_climate_crisis/transcript?language=en

base_url = 'https://www.ted.com'

list_of_talks.shape[0]
# Out:
# 4384

# %%
# Current url needs to be transformed a bit to get it into the right format to retrieve each separate transcript
list_of_talks.iloc[1]['url']
# Out:
# '/talks/wendy_de_la_rosa_a_simple_2_step_plan_for_saving_more_money/transcript?language=en'

# %%
# This cell only needs to run the very first time we load in the list of TED talks urls. After we convert all 
# urls to be in the correct format (containing '/transcript'), we don't need to run it again

# Add /transcript to the end of each url but insert it before ?language=en
#list_of_talks['url'] = list_of_talks['url'].str.replace ('?language', '/transcript?language', regex=False)

# %%
for row_index in range(list_of_talks.shape[0]):
#for row_index in range(641,642):

    # if this transcript was already found, skip it - this way I can re-run this code to try to fill in blank
    # trancripts that might have failed the first time.

  # if not nan, and not the empty string, then there is a transcript already saved in this record
    if pd.isna(list_of_talks.at[row_index, 'transcript']) == False and list_of_talks.at[row_index, 'transcript'] != '':
      #print (f'Current transcript:{list_of_talks.at[row_index, "transcript"]}**END**') 
        #print (f'Transcript found in row {row_index}, skip.')
        continue

    each_talk_url = list_of_talks.iloc[row_index]['url']

    resp = requests.get(base_url + each_talk_url)
    
    if resp.status_code != 200:
        print (f'Get failed. Status Code: {resp.status_code} ')
        print (f'URL failed: {base_url + each_talk_url} ')
        continue
    
    soup = BeautifulSoup(resp.text, 'html.parser')  # html.parser    

    #text_block = soup.select('div', class_ = ['d:n', 'f-w:700', 'f:.9', 'f:1@xxl', 'c:white']) 

    full_transcript = ''
    
    # Find tags for this talk, which are stored in a script tag with the format <script data-spec="q">
    
    tags = soup.body.find("script" , {'data-spec' : "q"})
    
    script_text = str(tags)      # convert from Tag object to str, so we can slice it up and extract list of talk tag values
    script_start = script_text.find('"tags":') + 8   # add 8 to get past "tags":[ 
    script_end = script_text.find(']', script_start)   # list of tags end with a ]
    tag_list = script_text[script_start:script_end].replace('"', "")  # remove double quotes from string
    #tag_list = tag_list.split(',')  # convert to list of values

    list_of_talks.at[row_index, 'tags'] = tag_list
    
    for tag in soup.find_all('div'):
        
        # if tag has all matching attributes of class 
        if tag.has_attr( "class" ):
            c = tag['class']

            # print (f'Div name: {tag.name} ')
            # print(f"Class name: {tag['class']}")
            # print(f'Text:{tag.text[0:200]} END OF TEXT')

            # this could work for talk views
            if 'f-w:700' in c and 'f:.9' in c and 'f:1@xxl' in c:
                temp_views = tag.text
                
                temp_views = temp_views.replace('\n', ' ')
                temp_views = temp_views.replace('\t', '')
                
                temp_views = " ".join(temp_views.split())
                
                list_of_talks.at[row_index, 'views'] = temp_views
        
                
            # Opening paragraph in transcript
#             if  'p:2' in c and 'p-t:4@md' in c:
#                 print (f'Transcript Open Div name: {tag.name} ')
#                 print(f" Transcript Open Class name: {tag['class']}")
#                 print(f'Transcript Open Text:{tag.text[0:200]} END OF TEXT')
                
            # every paragraph of main transcript text
            if  'Grid__cell' in c and 'flx-s:1' in c and 'p-r:4' in c:
                # Talk paragraphs found in this <div>
                # class=" Grid__cell flx-s:1 p-r:4 "
                               
                # print (f'Transcript Div name: {tag.name} ')
                # print(f" Transcript Class name: {tag['class']}")
                # print(f'Transcript Text:{tag.text[0:200]} END OF TEXT')
                
                full_transcript = full_transcript + tag.text
    
    # Strip out tabs and new line characters
    full_transcript = full_transcript.replace('\n', ' ')
    full_transcript = full_transcript.replace('\t', '')
    
    
    full_transcript = " ".join(full_transcript.split())
    
    list_of_talks.at[row_index, 'transcript'] = full_transcript
    
    if row_index % 500 == 0:
        print (f'{row_index} transcripts downloaded.')


    # TED's servers have a 'Retry-After': '5' value, so let's wait 6 seconds in between requests to be on the safe side.
    # Wait 6 sec before next request
    # This needs to be here just in case we skip a 

    time.sleep(6)
        
    
        

        
print (f'{row_index + 1} transcripts downloaded. End of downloading.')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-a2f45566f3e4> in <module>
#      94     # This needs to be here just in case we skip a
#      95
# ---> 96     time.sleep(6)
#      97
#      98
#
# KeyboardInterrupt:

# %%
list_of_talks.head()
# Out:
#                                                title  \
# 0  Community-powered solutions to the climate crisis
# 1         A simple 2-step plan for saving more money
# 2  What causes dandruff, and how do you get rid o...
# 3    The artist who won a Nobel Prize... in medicine
# 4         A concrete idea to reduce carbon emissions
#
#                                  speaker  \
# 0  Rahwa Ghirmatzion and Zelalem Adefris
# 1                       Wendy De La Rosa
# 2                       Thomas L. Dawson
# 3                      Melanie E. Peffer
# 4                        Karen Scrivener
#
#                                                  url month  year tags views  \
# 0  /talks/rahwa_ghirmatzion_and_zelalem_adefris_c...   Feb  2021  NaN   NaN
# 1  /talks/wendy_de_la_rosa_a_simple_2_step_plan_f...   Feb  2021  NaN   NaN
# 2  /talks/thomas_l_dawson_what_causes_dandruff_an...   Feb  2021  NaN   NaN
# 3  /talks/melanie_e_peffer_the_artist_who_won_a_n...   Feb  2021  NaN   NaN
# 4  /talks/karen_scrivener_a_concrete_idea_to_redu...   Feb  2021  NaN   NaN
#
#   transcript
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
list_of_talks.iloc[641]
# Out:
# title                          The first and last king of Haiti
# speaker                                            Marlene Daut
# url           /talks/marlene_daut_the_first_and_last_king_of...
# month                                                       Oct
# year                                                       2019
# tags          animation,TED-Ed,history,world cultures,educat...
# views                                      430,476 views • 4:48
# transcript    The royal couple of Haiti rode into their coro...
# Name: 641, dtype: object

# %%
list_of_talks.head(11)
# Out:
#                                                 title  \
# 0   Community-powered solutions to the climate crisis
# 1          A simple 2-step plan for saving more money
# 2   What causes dandruff, and how do you get rid o...
# 3     The artist who won a Nobel Prize... in medicine
# 4          A concrete idea to reduce carbon emissions
# 5              How a green economy could work for you
# 6      Why didn't this 2,000 year old body decompose?
# 7   How technology changes our sense of right and ...
# 8   TikTok, Instagram, Snapchat — and the rise of ...
# 9       What if every satellite suddenly disappeared?
# 10  How a geospatial nervous system could help us ...
#
#                                   speaker  \
# 0   Rahwa Ghirmatzion and Zelalem Adefris
# 1                        Wendy De La Rosa
# 2                        Thomas L. Dawson
# 3                       Melanie E. Peffer
# 4                         Karen Scrivener
# 5                          Angela Francis
# 6                        Carolyn Marshall
# 7                           Juan Enriquez
# 8                             Qiuqing Tai
# 9                              Moriba Jah
# 10                        Jack Dangermond
#
#                                                   url month  year  \
# 0   /talks/rahwa_ghirmatzion_and_zelalem_adefris_c...   Feb  2021
# 1   /talks/wendy_de_la_rosa_a_simple_2_step_plan_f...   Feb  2021
# 2   /talks/thomas_l_dawson_what_causes_dandruff_an...   Feb  2021
# 3   /talks/melanie_e_peffer_the_artist_who_won_a_n...   Feb  2021
# 4   /talks/karen_scrivener_a_concrete_idea_to_redu...   Feb  2021
# 5   /talks/angela_francis_how_a_green_economy_coul...   Feb  2021
# 6   /talks/carolyn_marshall_why_didn_t_this_2_000_...   Feb  2021
# 7   /talks/juan_enriquez_how_technology_changes_ou...   Feb  2021
# 8   /talks/qiuqing_tai_tiktok_instagram_snapchat_a...   Feb  2021
# 9   /talks/moriba_jah_what_if_every_satellite_sudd...   Feb  2021
# 10  /talks/jack_dangermond_how_a_geospatial_nervou...   Feb  2021
#
#                                             tags                  views  \
# 0                                            NaN                    NaN
# 1                                            NaN                    NaN
# 2                                            NaN                    NaN
# 3                                            NaN                    NaN
# 4                                            NaN                    NaN
# 5                                            NaN                    NaN
# 6                                            NaN                    NaN
# 7                                            NaN                    NaN
# 8                                            NaN                    NaN
# 9                                            NaN                    NaN
# 10  map,data,decision-making,technology,software  595,995 views • 22:12
#
#                                            transcript
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Simone Ross: Jack, I would love you to tell us...

# %%
#list_of_talks['tags'] = list_of_talks['tags'].split(',')

# %% [markdown]
# Create a record for each talk containing:
# * Title
# * Speaker
# * URL
# * Date

# %%
# Save to csv
#list_of_talks.to_csv('./transcripts.csv', index=False)

# %%
list_of_talks.isnull().sum()
